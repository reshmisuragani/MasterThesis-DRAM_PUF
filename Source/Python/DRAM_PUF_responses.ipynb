# %%
import os
cwd = os.getcwd()
f = open(r"output1.txt", "rb")
num = list(f.read())
b = ''.join('{:08b}'.format(c) for c in num)
print(num)
#for x in num:
#    print(hex(x))
# Out:
# [20, 50, 16, 207, 4, 63, 4, 192, 128, 151, 128, 80, 19, 94, 8, 6, 10, 98, 70, 101, 32, 168, 0, 108, 8, 212, 64, 22, 16, 6, 128, 150, 68, 96, 32, 91, 160, 41, 0, 237, 0, 177, 32, 24, 0, 141, 18, 165, 1, 52, 12, 197, 0, 252, 16, 66, 1, 59, 17, 140, 13, 93, 1, 0, 18, 15, 144, 133, 16, 240, 134, 18, 64, 3, 0, 184, 3, 113, 0, 92, 4, 9, 144, 169, 146, 113, 4, 72, 128, 169, 24, 4, 65, 24, 0, 130, 64, 16, 16, 155, 4, 119, 16, 85, 145, 48, 144, 216, 2, 93, 134, 69, 8, 196, 224, 50, 0, 2, 130, 191, 36, 71, 0, 36, 72, 0, 9, 154, 64, 81, 8, 0, 8, 6, 0, 183, 66, 69, 32, 32, 0, 0, 10, 190, 88, 212, 2, 18, 0, 6, 128, 183, 144, 129, 0, 189, 14, 17, 38, 156, 40, 209, 0, 1, 32, 135, 64, 165, 16, 159, 16, 196, 70, 4, 64, 128, 33, 208, 0, 10, 88, 69, 0, 1, 17, 207, 0, 4, 0, 68, 2, 2, 2, 240, 200, 74, 0, 204, 0, 0, 130, 115, 6, 28, 4, 13, 18, 164, 36, 176, 128, 202, 4, 221, 130, 0, 82, 82, 0, 78, 68, 133, 0, 160, 96, 33, 32, 233, 0, 211, 128, 13, 0, 110, 128, 68, 32, 228, 16, 98, 1, 13, 160, 164, 0, 80, 
# ...
